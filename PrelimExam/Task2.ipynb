# %% [markdown]
# # Text Processing Script
# **Prelim Task2**
#
# This Python script reads a file and performs basic text analysis using regular expressions (regex).
#
# ### Main Functionalities:
#
# 1. **File Reading (`read_file`)**:
#    - Reads content from a file.
#    - Returns the content as a string.
#
# 2. **Regex Search (`regEX`)**:
#    - Finds numbers, words, and email addresses in the text.
#    - Returns matches for each pattern.
#
# 3. **Sentence Search (`find_sentences_starting_with`)**:
#    - Finds sentences starting with a specific word (case-insensitive).
#
# 4. **Email Extraction (`find_all_emails`)**:
#    - Extracts all email addresses from the text.
#
# 5. **Basic Stats (`process_text`)**:
#    - Generates a report with the count, total, min, max, and average for numbers found.

# %%
import re

def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
        return content
    except FileNotFoundError:
        print('File not found.')
        return ''


def regEX(content):
    # regEX Patterns
    patterns = {
        'Numbers': r'\b\d+\b',
        'Words': r'\b[A-Za-z]+\b',
        'Emails': r'[\w\.-]+@[\w\.-]+'  
    }

    results = {}
    for key, pattern in patterns.items():
        matches = re.findall(pattern, content)
        results[key] = matches

    return results


def find_sentences_starting_with(content, word):
    pattern = rf'(?i)\b{word}\b[^.?!]*[.?!]'
    sentences = re.findall(pattern, content)
    return sentences


def find_all_emails(content):
    pattern = r'[\w\.-]+@[\w\.-]+'
    emails = re.findall(pattern, content)
    return emails

def get_min(numbers):
    min_num = numbers[0]
    for num in numbers:
        if num < min_num:
            min_num = num
    return min_num

def get_max(numbers):
    max_num = numbers[0]
    for num in numbers:
        if num > max_num:
            max_num = num
    return max_num


def process_text(results):
    report = {}
    for key, matches in results.items():
        count = len(matches)

        # Collect numbers
        numbers = []
        if key == 'Numbers':
            for num in matches:
                if num.isdigit():
                    numbers.append(int(num))

        # Total Values
        if key == 'Numbers':
            if numbers:
                totals = sum(numbers)
                min_value = get_min(numbers)
                max_value = get_max(numbers)
                average = totals / count if count > 0 else 'None Found'
            else:
                totals = 'None Found'
                min_value = 'None Found'
                max_value = 'None Found'
                average = 'None Found'
        else:
            totals = 'N/A'
            min_value = 'None Found'
            max_value = 'None Found'
            average = 'None Found'


        report[key] = {
            'Count': count,
            'Total': totals,
            'Minimum': min_value,
            'Maximum': max_value,
            'Average': average
        }
    
    return report



file_path = 'virus.txt' # FILE
content = read_file(file_path)
if content:
    results = regEX(content)
    report = process_text(results)

    print('\nRegex Search Result:\n')S
    for key, data in report.items():
        print(f'{key}:')
        for k, v in data.items():
            print(f'  {k}: {v}')

    # Print sentences starting with a specific word
    word_to_search = 'virus'  # Can change to any word
    sentences = find_sentences_starting_with(content, word_to_search)
    print(f"\nSentences starting with '{word_to_search}':")
    for sentence in sentences:
        print(f'- {sentence.strip()}')

    # Print all emails found in the text
    emails = find_all_emails(content)
    print("--------------------------------------------")
    print("\nAll Emails Found:")
    for email in emails:
        print(f'- {email}')
# Out:
# Regex Search Result:
#
# Numbers:
#   Count: 404
#   Total: 53091
#   Minimum: 0
#   Maximum: 9600
#   Average: 131.41336633663366
# Words:
#   Count: 12387
#   Total: N/A
#   Minimum: None Found
#   Maximum: None Found
#   Average: None Found
# Emails:
#   Count: 2
#   Total: N/A
#   Minimum: None Found
#   Maximum: None Found
#   Average: None Found
#
# Sentences starting with 'virus':
# - Virus Tools and Techniques
#
# W.
# - virus tools are now available to help manage this threat.
# - virus tools.
# - Virus Removal Tools
#     4.
# - Virus Techniques
#   5.
# - Virus Tools
#     5.
# - virus tools are discussed, as well as suggestions of
# appropriate applications for these tools.
# - virus tools, regardless of platform.
# - virus tools have focused on personal computers since these systems are
# currently at the greatest risk of infection.
# - virus tools for an organization.
# - virus products and follows with selection criteria which must
# be considered to ensure practicality and convenience.
# - virus tools (e.
# - virus tools.
# - virus problem is most pressing in the
# personal computer arena.
# - virus tools are
# available as personal computer products.
# - virus tools.
# - virus tools.
# - virus field.
# - virus is a self-replicating code segment which must be attached to a host
# executable.
# - virus code also executes.
# - virus will replicate by attaching a copy of itself to another
# executable.
# - virus may include an additional "payload" that triggers when
# specific conditions are met.
# - virus, except a Trojan horse does not replicate.
# - virus is often described as a Trojan horse.
# - virus-infected
# programs.
# - virus that is generated by modifying a known virus.
# - virus will destroy code or data in the host program by replacing
# it with the virus code.
# - virus is more likely to be detected and deleted if the program ceases to work.
# - virus is designed to append the virus code to the physical
# end of the program or to move the original code to another location.
# - virus determines whether
# or not an executable is already infected.
# - virus is to avoid multiple infections of a
# single executable.
# - virus.
# - virus installs itself as part of the operating system upon execution
# of an infected host program.
# - virus will remain resident until the system is
# shut down.
# - virus is available to infect
# all suitable hosts that are accessed.
# - virus is a resident virus that attempts to evade detection by
# concealing its presence in infected files.
# - virus
# intercepts system calls which examine the contents or attributes of infected
# files.
# - virus might remove the virus code from
# an executable when it is read (rather than executed) so that an anti-virus
# software package will examine the original, uninfected host program.
# - virus has two parts: a small decryptor and the encrypted virus
# body.
# - virus is executed, the decryptor will execute first and decrypt
# the virus body.
# - virus body can execute, replicating or becoming
# resident.
# - virus body will include an encryptor to apply during replication.
# - virus will use different encryption keys or encryption
# algorithms.
# - virus creates copies during replication that are functionally
# equivalent but have distinctly different byte streams.
# - virus may randomly insert superfluous instructions, interchange the order of
# independent instructions, or choose from a number of different encryption
# schemes.
# - virus difficult to locate, identify,
# or remove.
# - virus is one that has been written, but has never been unleashed on
# the public.
# - virus writers.
# - virus or different viruses.
# - virus tools perform three basic functions.
# - virus before it
# executes, during execution, or after execution.
# - virus has been detected.
# - virus on a system.
# - virus may be
# actively executing, residing in memory, or stored in executable code.
# - virus
# may be detected before execution, during execution, or after execution and
# replication.
# - virus must infect other host programs.
# - virus-infected programs as the virus attempts to
# replicate or become resident.
# - virus has been introduced to the
# system and attempts to replicate before detection can occur.
# - virus has replicated.
# - virus has infected a particular
# executable.
# - virus.
# - virus has been detected it is found on numerous systems
# or in numerous executables on a single system.
# - virus code from the
# infected executable.
# - virus warnings.
# - virus is the important
# point.
# - virus tools.
# - virus tools make errors.
# - virus tool, accuracy is not as great a concern.
# - virus infection is somewhat frightening and very confusing.
# - virus tool is supplying false information, this will make a bad situation
# worse.
# - virus.
# - virus,
# this is known as a false positive (this is also known as a Type I error.
# - virus has infected a particular executable.
# - virus or
# assigns the wrong name to the virus.
# - virus should be a simple task, but
# in fact it is not.
# - virus research
# community as to what constitutes "different" viruses.
# - virus identification tools.
# - virus as another variant of that virus for
# a variety of reasons.
# - virus must be considered along with the degree of precision.
# - virus.
# - virus than the actual infector.
# - virus tools installed.
# - virus tools.
# - virus effort.
# - virus
# techniques:
#
# 	o signature scanning and algorithmic detection
# 	o general purpose monitors
# 	o access control shells
# 	o checksums  for change detection
# 	o knowledge-based removal tools
# 	o research efforts
# 		- heuristic binary analysis
# 		- precise identification
# 	o other tools
# 		- system utilities as removal tools
# 		- inoculation
#
#
#
# For detection of viruses, there are five classes of techniques: signature
# scanning and algorithmic detection; general purpose monitors; access control
# shells; checksums for change detection; and heuristic binary analysis.
# - virus disinfectors, and general disinfecting programs.
# - virus tools employs the complementary techniques of
# signature scanning and algorithmic detection.
# - virus).
# - virus detected).
# - virus code, but
# they can also be used to detect resident viruses by scanning memory instead of
# executables.
# - virus produces a
# warning message.
# - virus or virus family with which it is infected.
# - virus signature, which are unique to a particular virus, or
# a family of viruses.
# - virus signatures are generated by examining samples of
# the virus.
# - virus
# signature.
# - virus you are likely
# to encounter.
# - virus signature in the scanner's database.
# - virus is memory-resident at the time the scanner executes, the virus may hide
# itself.
# - virus that was unknown at the time the scanner was built.
# - virus is
# encountered.
# - virus is present.
# - virus scanners are
# immediately out of date.
# - virus detection, procedures must be devised for distribution of updates.
# - virus
# solution.
# - virus discovered after the
# program was released) and any such detection will result in misidentification.
# - virus or virus family.
# - virus infections at any given time.
# - virus that has infected it.
# - virus detected" as "No virus exists.
# - virus-like or otherwise malicious behavior.
# - virus is a code
# stream, there is a very real possibility that legitimate programs will perform
# the same actions, causing the alarms to sound.
# - virus would not be detected by the monitoring program.
# - virus-like behavior are also
# not fool-proof.
# - virus-specific, so it will not require updating until new
# virus techniques are devised.
# - virus technology is developed, a number of variations
# emerge.
# - virus doesn't perform any
# activities the monitor deems suspicious.
# - virus-like behavior, the shell
# attempts to enforce an access control policy for the system.
# - virus or Trojan
# horse working in an expected manner.
# - virus uses methods that the access control
# shell does not monitor, the monitor will produce false negatives.
# - virus can modify any program
# that its host program is authorized to modify.
# - virus to
# replicate and is another source of false negatives.
# - virus or
# activation of a Trojan horse.
# - virus replication does
# not conflict with the user's access table entries.
# - virus
# infection.
# - virus problem.
# - virus detection tools.
# - virus, since they look for modifications in executables.
# - virus to replicate.
# - virus cannot escape detection.
# - virus has replicated.
# - virus.
# - virus-free when
# the checksums are calculated; resident viruses may fool the change detection
# software.
# - virus
# tools.
# - virus
# or simply a result of self-modification.
# - virus infection,
# self-modification, recompilation, or modification of the baseline.
# - Virus Removal Tools
#
# The primary means of automated removal of virus infection is knowledge-based
# removal tools.
# - virus
# makes to a file.
# - virus to determine its effects on
# an infected file, a suitable algorithm is developed for disinfecting files.
# - virus.
# - virus
# disinfectors are usually developed as the result of a particularly virulent
# outbreak of a virus.
# - virus removal programs,
# containing removal algorithms for several viruses.
# - virus, removal is not possible.
# - virus itself.
# - virus and the lack of quality assurance
# among virus writers.
# - virus more
# than once, or by more than one virus).
# - virus is removed.
# - virus is necessary to ensure that the correct
# removal algorithm is used.
# - virus researchers
# generally dislike removal programs and discourage their use.
# - virus field.
# - virus-like
# behavior.
# - virus-like actions, a warning is
# displayed.
# - virus-like code.
# - virus code avoids use of those techniques common to viruses.
# - virus writers.
# - virus has been detected, a precise identification tool would be
# invoked in order to more accurately identify the virus.
# - Virus scanners, currently the most common virus detection method, generally
# employ signature scanning to detect and identify viruses.
# - virus.
# - virus must match, not just a subset of the virus (i.
# - virus map" to represent the
# contents of the virus.
# - virus map contains checksum values for all constant
# parts of the virus code.
# - virus that contain
# variable information such as text or system dependent data values.
# - virus corresponding to the map.
# - virus (or is uninfected.
# - virus map database.
# - virus is new or has no
# corresponding entry in the database, the precise identification tool should
# always "fail" to identify the viruses.
# - virus
# "X," or unknown.
# - virus has been detected, the user wants to know exactly what virus he has and
# time is not a significant factor.
# - virus infecting their systems.
# - virus tools.
# - virus signatures.
# - virus itself, though.
# - virus is to be detected.
# - virus to the executable at the appropriate location.
# - virus tools and procedures.
# - virus.
# - virus from a network of PCs, inoculation might be considered as a
# desperation measure.
# - Virus Techniques
#
# The selection of the appropriate class of anti-virus tools requires answers to
# the following set of questions:
#
# 	o What is the probability of a virus infection?
# - virus infection?
# - virus infection.
# - Virus infections can
# occur whenever electronic information is shared.
# - virus infection.
# - virus (such as networks).
# - virus, may be extremely difficult
# to remove without appropriate tools.
# - virus
# infections are accounted for by a small number of viruses.
# - virus writers are particularly active [Bon91] are also more
# likely to encounter new viruses.
# - virus.
# - virus tools are subject to errors, but
# their relative frequencies vary widely.
# - virus tools are the
# ease of use and administrative overhead required for each tool.
# - virus detection.
# - virus identification.
# - virus (upon initial introduction to the system).
# - virus has entered the system.
# - virus can be modified to
# elude the scanner, but it will be detected by the checksum program.
# - virus
# detection.
# - virus removal continues to be deletion of the
# infected executable and restoration from a clean backup.
# - virus removal tools may be
# neglected.
# - Virus eradication through the removal of infected executables may
# require too much time and effort.
# - virus
# prior to disinfection is critical.
# - Virus Tools
#
# This section provides hypothetical scenarios for the use of anti-virus tools.
# - virus tools.
# - virus tools deemed necessary.
# - virus tools.
# - virus into the system.
# - virus is unable
# to spread if it can never be executed.
# - virus-free" before it is put into daily use.
# - virus tools is required
# to adequately perform this function, which must detect both known and future
# viruses.
# - virus will still most likely
# attempt to replicate.
# - virus protection.
# - virus behavior to detect.
# - virus detection.
# - virus technique has been selected, an appropriate tool from that
# class must be selected.
# - virus emerges between updates.
# - virus signatures, or are the
# 	signatures based on published search strings?
# - virus techniques?
# - virus techniques are discovered?
# - virus catalog or uses the same nameset as an available
# 	catalog.
# - virus information catalog will still
# apply.
# - virus you name.
# - virus.
# - virus field:
#
#
#
#   o	alerts regarding new viruses, Trojan horses, and other threats;
#   o	anti-virus product reviews (IBM PC and Macintosh);
#   o	technical papers on viruses, worms, and other threats;
#   o	anti-virus freeware and shareware;
#   o	and archives of the VIRUS-L forum.
# - virus product reviews examine and evaluate specific tools.
# - VIRUS-L forum has served as a world-wide discussion forum for the exchange of
# information regarding viruses since April 1988.
# - Virus
# Bulletin, pages 11-12, April 1992.
# - Virus Bulletin Conference", 1991.
# - Virus Factories", In
# "Proceedings of the First International Virus Bulletin Conference", 1991.
# - Virus & Security Conference", 1992.
# - Virus & Security Conference", 1992.
# --------------------------------------------
#
# All Emails Found:
# - rmvilla@gmail.com
# - ansarysaricala@gmail.com
