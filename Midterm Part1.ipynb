# %%
### import csv

class StartupFailures:
    def __init__(self, filename):
        self.filename = filename

    def add(self, record):
        with open(self.filename, 'a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(record)
        print("Record added successfully!\n")

    def print_records(self):
        with open(self.filename, 'r') as file:
            reader = csv.reader(file)
            for row in reader:
                print(row)

    def search(self, keyword):
        with open(self.filename, 'r') as file:
            reader = csv.reader(file)
            found = False
            for row in reader:
                if keyword in row:
                    print(row)
                    found = True
            if not found:
                print("No record found with the given keyword.\n")

    def delete(self, keyword):
        records = []
        with open(self.filename, 'r') as file:
            reader = csv.reader(file)
            records = [row for row in reader if keyword not in row]
        with open(self.filename, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerows(records)
        print("Record deleted successfully!\n")

def main():
    manager = StartupFailures('Startup Failures.csv')
    while True:
        print("\n1. Add new record")
        print("2. Display all records")
        print("3. Search record")
        print("4. Delete record")
        print("5. Exit")
        choice = input("Select an option: ")
        if choice == '1':
            record = input("Enter new record as comma-separated values: ").split(',')
            manager.add(record)
        elif choice == '2':
            manager.print_records()
        elif choice == '3':
            keyword = input("Enter keyword to search: ")
            manager.search(keyword)
        elif choice == '4':
            keyword = input("Enter keyword to delete record: ")
            manager.delete(keyword)
        elif choice == '5':
            print("Exiting program.")
            break
        else:
            print("Invalid option. Please try again.\n")

if __name__ == "__main__":
    main()
# Out:
# 1. Add new record
# 2. Display all records
# 3. Search record
# 4. Delete record
# 5. Exit
# Select an option:  1
# Enter new record as comma-separated values:  New Game, Game, 2(2023-2025)
# Record added successfully!
#
#
# 1. Add new record
# 2. Display all records
# 3. Search record
# 4. Delete record
# 5. Exit
# Select an option:  2
# ['Name', 'Sector', 'Years of Operation']
# ['99dresses', 'Retail Trade', '3 (2010-2013)']
# ['Ahalife', 'Retail Trade', '7 (2010-2017)']
# ['Airy Labs', 'Information', '2 (2010-2012)']
# ['AllRomance', 'Retail Trade', '10 (2006-2016)']
# ['Ampush', 'Professional Scientific and Technical Services', '13 (2010-2023)']
# ['Anki', 'Manufacturing', '9 (2010-2019)']
# ['Aria Insights', 'Manufacturing', '11 (2008-2019)']
# ['Arivale', 'Health Care', '4 (2015-2019)']
# ['Aryballe', 'Manufacturing', '8 (2014-2022)']
# ['Ask Jeeves', 'Information', '11 (1996-2007)']
# ['Atrium', 'Professional Scientific and Technical Services', '4 (2017-2021)']
# ...
